items?clean=true&format=html&limit=1000&view=overview",
          "https://api.apify.com/v2/datasets/p6kC6lF5HPlwtMOKx/items?clean=true&format=html&limit=1000&view=overview",
          "https://api.apify.com/v2/datasets/8YMJudB8yPfghyb42/items?clean=true&format=html&limit=1000&view=overview",
          "https://api.apify.com/v2/datasets/h4uoe9izDNI5hSkK7/items?clean=true&format=html&limit=1000&view=overview",
          "https://api.apify.com/v2/datasets/wybMOGzDaHZJReuHP/items?clean=true&format=html&limit=1000&view=overview",
          "https://api.apify.com/v2/datasets/r4VoE3oKQeOQO5jxe/items?clean=true&format=html&limit=1000&view=overview",
          "https://api.apify.com/v2/datasets/nZOBfPG5DmMundJ1O/items?clean=true&format=html&limit=1000&view=overview",
          "https://api.apify.com/v2/datasets/XU6Xsg0XGjePYpBKZ/items?clean=true&format=html&limit=1000&view=overview",
          "https://api.apify.com/v2/datasets/jggbKNKg9a3fh8mHO/items?clean=true&format=html&limit=1000&view=overview",
          "https://api.apify.com/v2/datasets/qfSuoc6AmlDabocGt/items?clean=true&format=html&limit=1000&view=overview",
          "https://api.apify.com/v2/datasets/2f4ZBO7d872Gwfhck/items?clean=true&format=html&limit=1000&view=overview",
          "https://api.apify.com/v2/datasets/LRvbWesm7TuWPZ4ta/items?clean=true&format=html&limit=1000&view=overview",
          "https://api.apify.com/v2/datasets/lRTt2cK6fF2tbgxzG/items?clean=true&format=html&limit=1000&view=overview",
          "https://api.apify.com/v2/datasets/QEaxELZPa3ZuYFCgx/items?clean=true&format=html&limit=1000&view=overview",
          "https://api.apify.com/v2/datasets/a5QsgmGa47TL8CmFA/items?clean=true&format=html&limit=1000&view=overview",
          "https://api.apify.com/v2/datasets/oXJyxHReqOvJoifR0/items?clean=true&format=html&limit=1000&view=overview",
          "https://api.apify.com/v2/datasets/IwF5fM5RFHFxfhRLm/items?clean=true&format=html&limit=1000&view=overview",
          "https://api.apify.com/v2/datasets/yy3eLCZakKeL068PH/items?clean=true&format=html&limit=1000&view=overview",
          "https://api.apify.com/v2/datasets/hxW6wNvA4PPb5nPZH/items?clean=true&format=html&limit=1000&view=overview",
          "https://api.apify.com/v2/datasets/c6wuSqVKop1eOml4d/items?clean=true&format=html&limit=1000&view=overview",
          "https://api.apify.com/v2/datasets/ysrAdAJOpwlt42Pde/items?clean=true&format=html&limit=1000&view=overview",
          "https://api.apify.com/v2/datasets/glSxUm295iByufIbf/items?clean=true&format=html&limit=1000&view=overview",
          "https://api.apify.com/v2/datasets/NHIrXob4tHAQB0abq/items?clean=true&format=html&limit=1000&view=overview",
          "https://api.apify.com/v2/datasets/vNtIJa2FheMspoSiQ/items?clean=true&format=html&limit=1000&view=overview",
          "https://api.apify.com/v2/datasets/JliCwNsufLaTS6cdP/items?clean=true&format=html&limit=1000&view=overview",
          ]

# %%
# # soup = BeautifulSoup(response.content, 'html.parser')
# soup = BeautifulSoup(response.content, 'html.parser')

# # Find all rows in the table (excluding header rows)
# table_rows = soup.find_all('tr')[1:]

# # Extract column headers from the first row (thead)
# headers = [header.get_text(strip=True) for header in soup.find_all('th')]
# for header in soup.find_all('th'):
#     header.get_text(strip=True) 

# # Initialize an empty list to store rows of data
# data = []

# # Iterate through each row and extract data into the list of dictionaries
# for row in table_rows:
#     data.append({headers[i]: td.get_text(strip=True) for i, td in enumerate(row.find_all('td'))})

# # Create DataFrame from the list of dictionaries
# df = pd.DataFrame(data)

# # Display the DataFrame
# print(df)
# len(urlList)

# %%
merged_df = pd.read_csv("../data/scrapfirst.csv")

# %%
# urlList = ["https://api.apify.com/v2/datasets/KuMsMx0rw1I4fYWVF/items?clean=true&format=html&limit=1000&view=overview",
#        "https://api.apify.com/v2/datasets/mAZQAdvvo2aJptL7k/items?clean=true&format=html&limit=1000&view=overview",]


for url in urlList:
    response = requests.get(url)
    df_list = pd.read_html(StringIO(response.text))
    df = df_list[0]
    merged_df = pd.concat([merged_df, df], ignore_index=True)



# Display the DataFrame
print(merged_df)
merged_df.to_csv("../data/scrap.csv", index=False,encoding='utf-8')
# Out:
#                                                     url  \
# 0     https://x.com/taranath_bhatt/status/1807112470...
# 1     https://x.com/klamichhane/status/1807053896587...
# 2     https://x.com/RepublicaNepal/status/1807031275...
# 3     https://x.com/RepublicaNepal/status/1807030978...
# 4     https://x.com/WHH_Nepal/status/180702974483730...
# ...                                                 ...
# 9305  https://x.com/RepublicaNepal/status/1133928714...
# 9306  https://x.com/RepublicaNepal/status/1133924827...
# 9307  https://x.com/PuskarAdhikar/status/11339232874...
# 9308  https://x.com/RepublicaNepal/status/1133913423...
# 9309   https://x.com/Deseret/status/1133905866795565056
#
#                                              twitterUrl                   id  \
# 0     https://twitter.com/taranath_bhatt/status/1807...  1807112470659514445
# 1     https://twitter.com/klamichhane/status/1807053...  1807053896587919743
# ...
